# %%
from pydub import AudioSegment

# === SETTINGS ===
input_mp3_path = "1.6.mp3"  # Path to your MP3 file
output_wav_path = "sir_audio.wav"     # Path to save WAV file

# === CONVERSION ===
# Load the MP3 file
audio = AudioSegment.from_mp3(input_mp3_path)

# Export as WAV
audio.export(output_wav_path, format="wav")

print(f"✅ Successfully converted {input_mp3_path} to {output_wav_path}")
# Out:
# ✅ Successfully converted 1.6.mp3 to sir_audio.wav

# %%
import os
import subprocess
from pydub import AudioSegment

# === CONFIGURATION ===
FULL_AUDIO = 'sir.wav'
FINAL_AUDIO = 'finetuning_audio.wav'

# === Step 1: Load and convert trimmed audio to mono ===

audio = AudioSegment.from_file("sir_audio.wav")
audio = audio.set_channels(1).set_frame_rate(48000)
audio.export(FINAL_AUDIO, format="wav")
print(f"✅ Final converted audio saved as: {FINAL_AUDIO}")
print(f"Channels: {audio.channels}")
print(f"Frame rate (sample rate): {audio.frame_rate}")
# Out:
# ✅ Final converted audio saved as: finetuning_audio.wav
# Channels: 1
# Frame rate (sample rate): 48000

# %%
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence

def segment_audio(input_file, output_dir="tts_dataset_hindi_48k", min_duration=3, max_duration=7, silence_thresh=None, min_silence_len=500):
    # Load full audio
    audio = AudioSegment.from_file(input_file)
    total_original_duration = len(audio) / 1000.0  # in seconds
    print(f"🎧 Total original audio duration: {total_original_duration:.2f} seconds")

    # Set silence threshold dynamically if not provided
    if silence_thresh is None:
        silence_thresh = audio.dBFS - 14

    # Split based on silence
    chunks = split_on_silence(audio,
                              min_silence_len=min_silence_len,
                              silence_thresh=silence_thresh,
                              keep_silence=250)

    os.makedirs(output_dir, exist_ok=True)

    chunk_count = 0
    temp_chunk = AudioSegment.empty()
    total_chunks_duration = 0.0  # Accumulate durations of all saved chunks

    for chunk in chunks:
        if len(temp_chunk) + len(chunk) < max_duration * 1000:
            temp_chunk += chunk
        else:
            if len(temp_chunk) >= min_duration * 1000:
                chunk_filename = f"chunk_{chunk_count:04d}.wav"
                temp_chunk.export(os.path.join(output_dir, chunk_filename), format="wav")
                duration_sec = len(temp_chunk) / 1000.0
                total_chunks_duration += duration_sec
                print(f"💾 Saved {chunk_filename}: Duration = {duration_sec:.2f}s")
                chunk_count += 1
                temp_chunk = chunk
            else:
                temp_chunk += chunk

    # Save remaining audio
    if len(temp_chunk) >= min_duration * 1000:
        chunk_filename = f"chunk_{chunk_count:04d}.wav"
        temp_chunk.export(os.path.join(output_dir, chunk_filename), format="wav")
        duration_sec = len(temp_chunk) / 1000.0
        total_chunks_duration += duration_sec
        print(f"💾 Saved {chunk_filename}: Duration = {duration_sec:.2f}s")

    # Final summary
    print("\n📊 Summary:")
    print(f"🔹 Total original audio duration   : {total_original_duration:.2f} seconds")
    print(f"🔹 Total duration of all chunks    : {total_chunks_duration:.2f} seconds")
    print(f"🔹 Number of chunks created        : {chunk_count + 1}")

    # Optional warning
    diff = abs(total_original_duration - total_chunks_duration)
    if diff > 1.0:
        print(f"⚠️ Warning: Duration mismatch of {diff:.2f} seconds due to silence trimming or rounding.")

# Example usage
segment_audio("finetuning_audio.wav")
# Out:
# 🎧 Total original audio duration: 1833.17 seconds
# 💾 Saved chunk_0000.wav: Duration = 10.06s
# 💾 Saved chunk_0001.wav: Duration = 15.97s
# 💾 Saved chunk_0002.wav: Duration = 5.06s
# 💾 Saved chunk_0003.wav: Duration = 6.13s
# 💾 Saved chunk_0004.wav: Duration = 6.58s
# 💾 Saved chunk_0005.wav: Duration = 6.76s
# 💾 Saved chunk_0006.wav: Duration = 6.92s
# 💾 Saved chunk_0007.wav: Duration = 3.04s
# 💾 Saved chunk_0008.wav: Duration = 4.17s
# 💾 Saved chunk_0009.wav: Duration = 6.57s
# 💾 Saved chunk_0010.wav: Duration = 4.68s
# 💾 Saved chunk_0011.wav: Duration = 5.96s
# 💾 Saved chunk_0012.wav: Duration = 6.63s
# 💾 Saved chunk_0013.wav: Duration = 8.53s
# 💾 Saved chunk_0014.wav: Duration = 7.20s
# 💾 Saved chunk_0015.wav: Duration = 6.76s
# 💾 Saved chunk_0016.wav: Duration = 4.20s
# 💾 Saved chunk_0017.wav: Duration = 8.19s
# 💾 Saved chunk_0018.wav: Duration = 5.67s
# 💾 Saved chunk_0019.wav: Duration = 7.20s
# 💾 Saved chunk_0020.wav: Duration = 7.37s
# 💾 Saved chunk_0021.wav: Duration = 6.95s
# 💾 Saved chunk_0022.wav: Duration = 7.38s
# 💾 Saved chunk_0023.wav: Duration = 6.40s
# 💾 Saved chunk_0024.wav: Duration = 6.45s
# 💾 Saved chunk_0025.wav: Duration = 6.96s
# 💾 Saved chunk_0026.wav: Duration = 5.60s
# 💾 Saved chunk_0027.wav: Duration = 5.70s
# 💾 Saved chunk_0028.wav: Duration = 5.07s
# 💾 Saved chunk_0029.wav: Duration = 6.03s
# 💾 Saved chunk_0030.wav: Duration = 6.73s
# 💾 Saved chunk_0031.wav: Duration = 5.20s
# 💾 Saved chunk_0032.wav: Duration = 6.77s
# 💾 Saved chunk_0033.wav: Duration = 5.42s
# 💾 Saved chunk_0034.wav: Duration = 6.14s
# 💾 Saved chunk_0035.wav: Duration = 6.09s
# 💾 Saved chunk_0036.wav: Duration = 4.10s
# 💾 Saved chunk_0037.wav: Duration = 6.49s
# 💾 Saved chunk_0038.wav: Duration = 6.86s
# 💾 Saved chunk_0039.wav: Duration = 6.74s
# 💾 Saved chunk_0040.wav: Duration = 5.84s
# 💾 Saved chunk_0041.wav: Duration = 6.67s
# 💾 Saved chunk_0042.wav: Duration = 6.43s
# 💾 Saved chunk_0043.wav: Duration = 6.73s
# 💾 Saved chunk_0044.wav: Duration = 5.05s
# 💾 Saved chunk_0045.wav: Duration = 4.82s
# 💾 Saved chunk_0046.wav: Duration = 5.12s
# 💾 Saved chunk_0047.wav: Duration = 6.13s
# 💾 Saved chunk_0048.wav: Duration = 6.52s
# 💾 Saved chunk_0049.wav: Duration = 6.68s
# 💾 Saved chunk_0050.wav: Duration = 7.95s
# 💾 Saved chunk_0051.wav: Duration = 4.68s
# 💾 Saved chunk_0052.wav: Duration = 6.36s
# 💾 Saved chunk_0053.wav: Duration = 7.00s
# 💾 Saved chunk_0054.wav: Duration = 8.47s
# 💾 Saved chunk_0055.wav: Duration = 6.59s
# 💾 Saved chunk_0056.wav: Duration = 5.79s
# 💾 Saved chunk_0057.wav: Duration = 5.18s
# 💾 Saved chunk_0058.wav: Duration = 6.08s
# 💾 Saved chunk_0059.wav: Duration = 4.88s
# 💾 Saved chunk_0060.wav: Duration = 6.30s
# 💾 Saved chunk_0061.wav: Duration = 6.76s
# 💾 Saved chunk_0062.wav: Duration = 4.26s
# 💾 Saved chunk_0063.wav: Duration = 6.76s
# 💾 Saved chunk_0064.wav: Duration = 4.95s
# 💾 Saved chunk_0065.wav: Duration = 4.97s
# 💾 Saved chunk_0066.wav: Duration = 6.80s
# 💾 Saved chunk_0067.wav: Duration = 6.88s
# 💾 Saved chunk_0068.wav: Duration = 7.01s
# 💾 Saved chunk_0069.wav: Duration = 9.73s
# 💾 Saved chunk_0070.wav: Duration = 3.93s
# 💾 Saved chunk_0071.wav: Duration = 6.31s
# 💾 Saved chunk_0072.wav: Duration = 6.46s
# 💾 Saved chunk_0073.wav: Duration = 5.76s
# 💾 Saved chunk_0074.wav: Duration = 5.55s
# 💾 Saved chunk_0075.wav: Duration = 4.75s
# 💾 Saved chunk_0076.wav: Duration = 4.16s
# 💾 Saved chunk_0077.wav: Duration = 5.80s
# 💾 Saved chunk_0078.wav: Duration = 5.63s
# 💾 Saved chunk_0079.wav: Duration = 10.63s
# 💾 Saved chunk_0080.wav: Duration = 4.83s
# 💾 Saved chunk_0081.wav: Duration = 3.93s
# 💾 Saved chunk_0082.wav: Duration = 6.75s
# 💾 Saved chunk_0083.wav: Duration = 4.22s
# 💾 Saved chunk_0084.wav: Duration = 5.95s
# 💾 Saved chunk_0085.wav: Duration = 5.77s
# 💾 Saved chunk_0086.wav: Duration = 6.57s
# 💾 Saved chunk_0087.wav: Duration = 3.99s
# 💾 Saved chunk_0088.wav: Duration = 6.40s
# 💾 Saved chunk_0089.wav: Duration = 7.22s
# 💾 Saved chunk_0090.wav: Duration = 4.31s
# 💾 Saved chunk_0091.wav: Duration = 6.25s
# 💾 Saved chunk_0092.wav: Duration = 6.78s
# 💾 Saved chunk_0093.wav: Duration = 6.57s
# 💾 Saved chunk_0094.wav: Duration = 5.90s
# 💾 Saved chunk_0095.wav: Duration = 6.33s
# 💾 Saved chunk_0096.wav: Duration = 5.72s
# 💾 Saved chunk_0097.wav: Duration = 5.05s
# 💾 Saved chunk_0098.wav: Duration = 5.59s
# 💾 Saved chunk_0099.wav: Duration = 5.05s
# 💾 Saved chunk_0100.wav: Duration = 6.33s
# 💾 Saved chunk_0101.wav: Duration = 4.13s
# 💾 Saved chunk_0102.wav: Duration = 6.26s
# 💾 Saved chunk_0103.wav: Duration = 4.23s
# 💾 Saved chunk_0104.wav: Duration = 7.28s
# 💾 Saved chunk_0105.wav: Duration = 4.40s
# 💾 Saved chunk_0106.wav: Duration = 6.85s
# 💾 Saved chunk_0107.wav: Duration = 4.80s
# 💾 Saved chunk_0108.wav: Duration = 6.99s
# 💾 Saved chunk_0109.wav: Duration = 4.46s
# 💾 Saved chunk_0110.wav: Duration = 7.87s
# 💾 Saved chunk_0111.wav: Duration = 4.50s
# 💾 Saved chunk_0112.wav: Duration = 11.06s
# 💾 Saved chunk_0113.wav: Duration = 6.44s
# 💾 Saved chunk_0114.wav: Duration = 4.70s
# 💾 Saved chunk_0115.wav: Duration = 6.32s
# 💾 Saved chunk_0116.wav: Duration = 3.10s
# 💾 Saved chunk_0117.wav: Duration = 5.47s
# 💾 Saved chunk_0118.wav: Duration = 6.30s
# 💾 Saved chunk_0119.wav: Duration = 3.48s
# 💾 Saved chunk_0120.wav: Duration = 6.70s
# 💾 Saved chunk_0121.wav: Duration = 5.25s
# 💾 Saved chunk_0122.wav: Duration = 3.48s
# 💾 Saved chunk_0123.wav: Duration = 6.83s
# 💾 Saved chunk_0124.wav: Duration = 7.58s
# 💾 Saved chunk_0125.wav: Duration = 10.09s
# 💾 Saved chunk_0126.wav: Duration = 3.62s
# 💾 Saved chunk_0127.wav: Duration = 7.82s
# 💾 Saved chunk_0128.wav: Duration = 16.25s
# 💾 Saved chunk_0129.wav: Duration = 6.02s
# 💾 Saved chunk_0130.wav: Duration = 3.68s
# 💾 Saved chunk_0131.wav: Duration = 5.53s
# 💾 Saved chunk_0132.wav: Duration = 6.83s
# 💾 Saved chunk_0133.wav: Duration = 6.65s
# 💾 Saved chunk_0134.wav: Duration = 6.54s
# 💾 Saved chunk_0135.wav: Duration = 4.82s
# 💾 Saved chunk_0136.wav: Duration = 6.73s
# 💾 Saved chunk_0137.wav: Duration = 5.94s
# 💾 Saved chunk_0138.wav: Duration = 3.66s
# 💾 Saved chunk_0139.wav: Duration = 6.37s
# 💾 Saved chunk_0140.wav: Duration = 4.64s
# 💾 Saved chunk_0141.wav: Duration = 5.30s
# 💾 Saved chunk_0142.wav: Duration = 6.43s
# 💾 Saved chunk_0143.wav: Duration = 6.75s
# 💾 Saved chunk_0144.wav: Duration = 6.21s
# 💾 Saved chunk_0145.wav: Duration = 6.72s
# 💾 Saved chunk_0146.wav: Duration = 4.87s
# 💾 Saved chunk_0147.wav: Duration = 4.90s
# 💾 Saved chunk_0148.wav: Duration = 6.63s
# 💾 Saved chunk_0149.wav: Duration = 7.21s
# 💾 Saved chunk_0150.wav: Duration = 5.95s
# 💾 Saved chunk_0151.wav: Duration = 3.93s
# 💾 Saved chunk_0152.wav: Duration = 4.47s
# 💾 Saved chunk_0153.wav: Duration = 5.53s
# 💾 Saved chunk_0154.wav: Duration = 12.44s
# 💾 Saved chunk_0155.wav: Duration = 3.05s
# 💾 Saved chunk_0156.wav: Duration = 6.59s
# 💾 Saved chunk_0157.wav: Duration = 6.51s
# 💾 Saved chunk_0158.wav: Duration = 4.87s
# 💾 Saved chunk_0159.wav: Duration = 4.18s
# 💾 Saved chunk_0160.wav: Duration = 6.65s
# 💾 Saved chunk_0161.wav: Duration = 6.44s
# 💾 Saved chunk_0162.wav: Duration = 6.32s
# 💾 Saved chunk_0163.wav: Duration = 5.92s
# 💾 Saved chunk_0164.wav: Duration = 3.51s
# 💾 Saved chunk_0165.wav: Duration = 3.79s
# 💾 Saved chunk_0166.wav: Duration = 4.95s
# 💾 Saved chunk_0167.wav: Duration = 7.48s
# 💾 Saved chunk_0168.wav: Duration = 5.26s
# 💾 Saved chunk_0169.wav: Duration = 5.84s
# 💾 Saved chunk_0170.wav: Duration = 6.29s
# 💾 Saved chunk_0171.wav: Duration = 6.58s
# 💾 Saved chunk_0172.wav: Duration = 4.37s
# 💾 Saved chunk_0173.wav: Duration = 6.48s
# 💾 Saved chunk_0174.wav: Duration = 6.68s
# 💾 Saved chunk_0175.wav: Duration = 6.35s
# 💾 Saved chunk_0176.wav: Duration = 6.20s
# 💾 Saved chunk_0177.wav: Duration = 5.70s
# 💾 Saved chunk_0178.wav: Duration = 6.17s
# 💾 Saved chunk_0179.wav: Duration = 6.46s
# 💾 Saved chunk_0180.wav: Duration = 4.03s
# 💾 Saved chunk_0181.wav: Duration = 5.90s
# 💾 Saved chunk_0182.wav: Duration = 7.34s
# 💾 Saved chunk_0183.wav: Duration = 5.96s
# 💾 Saved chunk_0184.wav: Duration = 6.60s
# 💾 Saved chunk_0185.wav: Duration = 3.90s
# 💾 Saved chunk_0186.wav: Duration = 4.61s
# 💾 Saved chunk_0187.wav: Duration = 6.04s
# 💾 Saved chunk_0188.wav: Duration = 5.10s
# 💾 Saved chunk_0189.wav: Duration = 6.93s
# 💾 Saved chunk_0190.wav: Duration = 6.11s
# 💾 Saved chunk_0191.wav: Duration = 6.61s
# 💾 Saved chunk_0192.wav: Duration = 6.39s
# 💾 Saved chunk_0193.wav: Duration = 6.48s
# 💾 Saved chunk_0194.wav: Duration = 6.55s
# 💾 Saved chunk_0195.wav: Duration = 6.18s
# 💾 Saved chunk_0196.wav: Duration = 3.02s
# 💾 Saved chunk_0197.wav: Duration = 4.17s
# 💾 Saved chunk_0198.wav: Duration = 6.93s
# 💾 Saved chunk_0199.wav: Duration = 6.38s
# 💾 Saved chunk_0200.wav: Duration = 6.92s
# 💾 Saved chunk_0201.wav: Duration = 5.11s
# 💾 Saved chunk_0202.wav: Duration = 5.53s
# 💾 Saved chunk_0203.wav: Duration = 4.07s
# 💾 Saved chunk_0204.wav: Duration = 6.66s
# 💾 Saved chunk_0205.wav: Duration = 4.85s
# 💾 Saved chunk_0206.wav: Duration = 6.89s
# 💾 Saved chunk_0207.wav: Duration = 3.87s
# 💾 Saved chunk_0208.wav: Duration = 10.29s
# 💾 Saved chunk_0209.wav: Duration = 6.38s
# 💾 Saved chunk_0210.wav: Duration = 6.52s
# 💾 Saved chunk_0211.wav: Duration = 6.89s
# 💾 Saved chunk_0212.wav: Duration = 4.27s
# 💾 Saved chunk_0213.wav: Duration = 6.95s
# 💾 Saved chunk_0214.wav: Duration = 8.46s
# 💾 Saved chunk_0215.wav: Duration = 9.43s
# 💾 Saved chunk_0216.wav: Duration = 6.11s
# 💾 Saved chunk_0217.wav: Duration = 3.23s
# 💾 Saved chunk_0218.wav: Duration = 3.92s
# 💾 Saved chunk_0219.wav: Duration = 5.91s
# 💾 Saved chunk_0220.wav: Duration = 8.00s
# 💾 Saved chunk_0221.wav: Duration = 6.89s
# 💾 Saved chunk_0222.wav: Duration = 6.79s
# 💾 Saved chunk_0223.wav: Duration = 5.38s
# 💾 Saved chunk_0224.wav: Duration = 3.09s
# 💾 Saved chunk_0225.wav: Duration = 4.03s
# 💾 Saved chunk_0226.wav: Duration = 6.94s
# 💾 Saved chunk_0227.wav: Duration = 8.09s
# 💾 Saved chunk_0228.wav: Duration = 4.31s
# 💾 Saved chunk_0229.wav: Duration = 6.14s
# 💾 Saved chunk_0230.wav: Duration = 6.94s
# 💾 Saved chunk_0231.wav: Duration = 5.47s
# 💾 Saved chunk_0232.wav: Duration = 6.62s
# 💾 Saved chunk_0233.wav: Duration = 6.57s
# 💾 Saved chunk_0234.wav: Duration = 5.99s
# 💾 Saved chunk_0235.wav: Duration = 4.52s
# 💾 Saved chunk_0236.wav: Duration = 6.62s
# 💾 Saved chunk_0237.wav: Duration = 6.67s
#
# 📊 Summary:
# 🔹 Total original audio duration   : 1833.17 seconds
# 🔹 Total duration of all chunks    : 1446.78 seconds
# 🔹 Number of chunks created        : 239
# ⚠️ Warning: Duration mismatch of 386.39 seconds due to silence trimming or rounding.

# %%
import os
from pydub import AudioSegment

def convert_to_16k(input_dir="tts_dataset_hindi_48k", output_dir="tts_dataset_hindi_16k"):
    os.makedirs(output_dir, exist_ok=True)

    wav_files = sorted([f for f in os.listdir(input_dir) if f.endswith(".wav")])
    print(f"🔍 Found {len(wav_files)} files in '{input_dir}'")

    for i, fname in enumerate(wav_files):
        input_path = os.path.join(input_dir, fname)
        output_path = os.path.join(output_dir, fname)

        # Load and convert
        audio = AudioSegment.from_wav(input_path)
        audio = audio.set_frame_rate(16000)  # Convert to 16kHz

        # Export to new location
        audio.export(output_path, format="wav")
        print(f"🎵 Converted and saved: {output_path}")

    print(f"\n✅ All files saved in '{output_dir}' as 16 kHz WAV.")

# Example usage
convert_to_16k()
# Out:
# 🔍 Found 238 files in 'tts_dataset_hindi_48k'
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0000.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0001.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0002.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0003.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0004.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0005.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0006.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0007.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0008.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0009.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0010.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0011.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0012.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0013.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0014.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0015.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0016.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0017.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0018.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0019.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0020.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0021.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0022.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0023.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0024.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0025.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0026.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0027.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0028.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0029.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0030.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0031.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0032.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0033.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0034.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0035.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0036.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0037.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0038.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0039.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0040.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0041.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0042.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0043.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0044.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0045.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0046.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0047.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0048.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0049.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0050.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0051.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0052.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0053.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0054.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0055.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0056.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0057.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0058.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0059.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0060.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0061.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0062.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0063.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0064.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0065.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0066.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0067.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0068.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0069.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0070.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0071.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0072.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0073.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0074.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0075.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0076.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0077.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0078.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0079.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0080.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0081.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0082.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0083.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0084.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0085.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0086.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0087.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0088.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0089.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0090.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0091.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0092.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0093.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0094.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0095.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0096.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0097.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0098.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0099.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0100.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0101.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0102.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0103.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0104.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0105.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0106.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0107.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0108.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0109.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0110.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0111.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0112.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0113.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0114.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0115.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0116.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0117.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0118.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0119.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0120.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0121.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0122.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0123.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0124.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0125.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0126.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0127.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0128.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0129.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0130.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0131.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0132.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0133.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0134.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0135.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0136.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0137.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0138.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0139.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0140.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0141.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0142.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0143.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0144.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0145.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0146.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0147.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0148.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0149.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0150.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0151.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0152.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0153.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0154.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0155.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0156.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0157.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0158.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0159.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0160.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0161.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0162.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0163.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0164.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0165.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0166.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0167.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0168.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0169.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0170.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0171.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0172.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0173.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0174.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0175.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0176.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0177.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0178.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0179.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0180.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0181.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0182.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0183.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0184.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0185.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0186.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0187.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0188.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0189.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0190.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0191.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0192.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0193.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0194.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0195.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0196.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0197.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0198.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0199.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0200.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0201.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0202.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0203.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0204.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0205.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0206.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0207.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0208.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0209.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0210.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0211.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0212.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0213.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0214.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0215.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0216.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0217.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0218.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0219.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0220.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0221.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0222.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0223.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0224.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0225.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0226.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0227.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0228.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0229.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0230.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0231.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0232.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0233.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0234.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0235.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0236.wav
# 🎵 Converted and saved: tts_dataset_hindi_16k/chunk_0237.wav
#
# ✅ All files saved in 'tts_dataset_hindi_16k' as 16 kHz WAV.

# %%
import os
import json
from joblib import Parallel, delayed
import subprocess

# === CONFIGURATION ===
#MODEL_PATH = "/home/karan/Fairseq-Inference/IndicWav2Vec_Hindi_SPRING_INX.pt"
MODEL_PATH = "/home/karan/Fairseq-Inference/SPRING_INX_data2vec_aqc_Hindi.pt"

AUDIO_DIR = "tts_dataset_hindi_16k"
SCRIPT_PATH = "infer_optimized.py"
OUTPUT_JSONL = "transcriptions.jsonl"

NUM_GPUS = 1  # You can set to 4 if needed
BATCH_SIZE = 209 # <<< DIRECTLY SET BATCH SIZE HERE

print(f"🛠️ Using BATCH_SIZE = {BATCH_SIZE}")

# === Load all .wav files
wav_files = sorted([os.path.join(AUDIO_DIR, f) for f in os.listdir(AUDIO_DIR) if f.endswith(".wav")])

# === Create batches
batches = [wav_files[i:i + BATCH_SIZE] for i in range(0, len(wav_files), BATCH_SIZE)]

print(f"🔢 Total batches: {len(batches)}")

# === Worker for one batch
def process_batch(batch_idx, batch_files):
    gpu_id = batch_idx % NUM_GPUS
    print(f"🚀 Processing batch {batch_idx} with {len(batch_files)} files on GPU {gpu_id}")

    cmd = ["python", SCRIPT_PATH, MODEL_PATH, str(gpu_id)] + batch_files

    result = subprocess.run(cmd, capture_output=True, text=True)
    if result.returncode != 0:
        print(f"❌ Error in batch {batch_idx}: {result.stderr.strip()}")
        return []

    lines = result.stdout.strip().splitlines()
    parsed = []
    for line in lines:
        try:
            res = eval(line)
            parsed.append(res)
        except Exception as e:
            print(f"⚠️ Parse error: {e} for line: {line}")
    return parsed

# === Parallel execution
all_results = Parallel(n_jobs=NUM_GPUS)(delayed(process_batch)(idx, batch) for idx, batch in enumerate(batches))

# === Flatten results
flat_results = [item for sublist in all_results for item in sublist]

# === Save final JSONL
with open(OUTPUT_JSONL, 'w', encoding='utf-8') as f:
    for item in flat_results:
        json.dump(item, f, ensure_ascii=False)
        f.write('\n')

print(f"\n✅ All transcriptions saved to {OUTPUT_JSONL}")
# Out:
# 🛠️ Using BATCH_SIZE = 209
# 🔢 Total batches: 2
# 🚀 Processing batch 0 with 209 files on GPU 0
# ❌ Error in batch 0: 2025-05-09 18:41:28.045960: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-09 18:41:28.047243: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-09 18:41:28.073641: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-09 18:41:28.472323: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/karan/Fairseq-Inference/fairseq-latest/fairseq/checkpoint_utils.py:340: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(f, map_location=torch.device("cpu"))
# Traceback (most recent call last):
#   File "infer_optimized.py", line 59, in <module>
#     output = transcribe_batch(model_path, audio_paths, device_id)
#   File "infer_optimized.py", line 17, in transcribe_batch
#     model, cfg, task = fairseq.checkpoint_utils.load_model_ensemble_and_task([model_path])
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/checkpoint_utils.py", line 502, in load_model_ensemble_and_task
#     model = task.build_model(cfg.model, from_checkpoint=True)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/audio_finetuning.py", line 254, in build_model
#     model = super().build_model(model_cfg, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/audio_pretraining.py", line 224, in build_model
#     model = super().build_model(model_cfg, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/fairseq_task.py", line 355, in build_model
#     model = models.build_model(cfg, self, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/__init__.py", line 106, in build_model
#     return model.build_model(cfg, task)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/wav2vec/wav2vec2_asr.py", line 224, in build_model
#     w2v_encoder = Wav2VecEncoder(cfg, len(task.target_dictionary))
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/wav2vec/wav2vec2_asr.py", line 454, in __init__
#     model = task.build_model(w2v_args.model, from_checkpoint=True)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/audio_pretraining.py", line 224, in build_model
#     model = super().build_model(model_cfg, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/fairseq_task.py", line 355, in build_model
#     model = models.build_model(cfg, self, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/__init__.py", line 101, in build_model
#     f"Could not infer model type from {cfg}. "
# KeyError: "'_name'"
# 🚀 Processing batch 1 with 29 files on GPU 0
# ❌ Error in batch 1: 2025-05-09 18:41:33.049752: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-09 18:41:33.051270: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-09 18:41:33.077496: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-09 18:41:33.563023: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/karan/Fairseq-Inference/fairseq-latest/fairseq/checkpoint_utils.py:340: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(f, map_location=torch.device("cpu"))
# Traceback (most recent call last):
#   File "infer_optimized.py", line 59, in <module>
#     output = transcribe_batch(model_path, audio_paths, device_id)
#   File "infer_optimized.py", line 17, in transcribe_batch
#     model, cfg, task = fairseq.checkpoint_utils.load_model_ensemble_and_task([model_path])
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/checkpoint_utils.py", line 502, in load_model_ensemble_and_task
#     model = task.build_model(cfg.model, from_checkpoint=True)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/audio_finetuning.py", line 254, in build_model
#     model = super().build_model(model_cfg, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/audio_pretraining.py", line 224, in build_model
#     model = super().build_model(model_cfg, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/fairseq_task.py", line 355, in build_model
#     model = models.build_model(cfg, self, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/__init__.py", line 106, in build_model
#     return model.build_model(cfg, task)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/wav2vec/wav2vec2_asr.py", line 224, in build_model
#     w2v_encoder = Wav2VecEncoder(cfg, len(task.target_dictionary))
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/wav2vec/wav2vec2_asr.py", line 454, in __init__
#     model = task.build_model(w2v_args.model, from_checkpoint=True)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/audio_pretraining.py", line 224, in build_model
#     model = super().build_model(model_cfg, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/tasks/fairseq_task.py", line 355, in build_model
#     model = models.build_model(cfg, self, from_checkpoint)
#   File "/home/karan/Fairseq-Inference/fairseq-latest/fairseq/models/__init__.py", line 101, in build_model
#     f"Could not infer model type from {cfg}. "
# KeyError: "'_name'"
#
# ✅ All transcriptions saved to transcriptions.jsonl
